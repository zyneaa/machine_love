# %%
import sys

assert sys.version_info >= (3, 7)

# %%
from packaging import version
import sklearn

assert version.parse(sklearn.__version__) >= version.parse("1.0.1")
print(sklearn.__version__)
# Out:
# 1.8.0

# %% [markdown]
# # Loggin into Kaggle

# %%
import kagglehub

kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %% [markdown]
# # Downloading dataset

# %%
from pathlib import Path
import pandas as pd

dataset_name = "algozee/teenager-menthal-healy"

download_path = kagglehub.dataset_download(dataset_name)
csv_file = list(Path(download_path).glob("*.csv"))[0]
data = pd.read_csv(csv_file)
# Out:
# Downloading to /Users/htetmyetlynn/.cache/kagglehub/datasets/algozee/teenager-menthal-healy/1.archive...
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 15.8k/15.8k [00:00<00:00, 516kB/s]
# Extracting files...
# '/Users/htetmyetlynn/.cache/kagglehub/datasets/algozee/teenager-menthal-healy/versions/1'

# %%
data = pd.read_csv(Path("datasets/housing/algozee/teenager-menthal-healy.csv"))

# %%
data.head()
